# %%
# %load_ext autoreload
# %load_ext tensorboard
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
from typing import Optional,List, Dict
from tqdm.notebook import tqdm

import datetime
import os
import copy

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from recs.evaluator import metrics

import tensorflow as tf
from tensorflow import keras as tfk
from tensorboard.plugins.hparams import api as hp

# %%
class QNet(tfk.layers.Layer):
    def __init__(
        self,
        num_items:int,
        seq_len:Optional[int]=3,
        hidden_dim:Optional[int]=100,
        embed_dim:Optional[int]=100,
        dropout_rate:Optional[int]=0.5,
        name="QNet"
    ):
        super(QNet, self).__init__(name=name)
        
        self._embedding = tfk.layers.Embedding(num_items, embed_dim, mask_zero=True)
        self._gru = tfk.layers.GRU(
            hidden_dim, 
            dropout=dropout_rate)

        self._qvalue_dense = tfk.layers.Dense(num_items+1, activation=None)
        self._imt_dense = tfk.layers.Dense(num_items, activation="softmax")
        self._lambda = tfk.layers.Lambda(
            lambda x: tf.expand_dims(x[:, 0], axis=-1) + x[:, 1:] - tf.reduce_mean(x[:, 1:], axis=-1, keepdims=True),
            output_shape=(num_items, )
        )
    
    def call(
        self, 
        item_seqs:tf.Tensor, # (batch_size, seq_len)
        training:Optional[bool]=False,
    ):
        x = self._embedding(item_seqs)
        x = self._gru(x, training=training)
        
        i = self._imt_dense(x)
        x = self._qvalue_dense(x)
        qvalue = self._lambda(x)
        return qvalue, i

# %%
class BCQRec(tfk.Model):
    
    def __init__(
        self,
        num_items:int,
        seq_len:int,
        hidden_dim:Optional[int]=100,
        embed_dim:Optional[int]=100,
        threshold:Optional[float]=0.3,
        dropout_rate:Optional[int]=0.5,
        gamma:Optional[float]=1.,
        lam:Optional[float]=1e-2,
        tau:Optional[int]=1.,
        update_count:Optional[int]=20,
        k:Optional[int]=20,
        name="BCQRec"
    ):
        super(BCQRec, self).__init__(name=name)
        self._qmodel = QNet(num_items, seq_len, hidden_dim, embed_dim, dropout_rate, name="BCQ")
        self._target_qmodel = copy.deepcopy(self._qmodel)
        
        self._num_items = num_items
        
        self._topk = k
        self._threshold = threshold
        self._gamma = gamma
        self._lam = lam
        self._iterations = 0
        self._update_count = update_count
        self._loss_tracker = tfk.metrics.Mean(name="loss")
        self._recall_tracker = tfk.metrics.Recall(name="recall")
        
        dummy_state = tf.zeros((1, seq_len), dtype=tf.int32)
        self._qmodel(dummy_state)
        self._target_qmodel(dummy_state)
        
    
    def compile(self, optimizer):
        super(BCQRec, self).compile()
        self.q_loss = tfk.losses.Huber()
        self.imt_loss = tfk.losses.CategoricalCrossentropy()
        self.optimizer = optimizer
    
    def call(self, state):
        q, imt =  self._qmodel(state)
        q = imt*q + (1-imt)*-1e8
        return q
    
    def train_step(self, data):
        self._iterations += 1
        state, action, reward, n_state, done = data
        onehot_act = tf.one_hot(action-1, depth=self._num_items)
        
        with tf.GradientTape() as tape:
            # Compute Target Q-value
            q, imt = self._qmodel(n_state)
            imt = tf.cast(imt / tf.reduce_max(imt, axis=1, keepdims=True) > self._threshold, dtype=tf.float32)

            next_action_val = imt*q + (1-imt)*-1e8
            next_action = tf.argmax(next_action_val, axis=-1)
            onehot_next_act = tf.one_hot(next_action, depth=self._num_items)
            
            q, imt = self._target_qmodel(n_state)
            target_q = reward + (1-done)*self._gamma*tf.reduce_sum(q*onehot_next_act, axis=-1)
            target_q = tf.stop_gradient(target_q)
            
            # Get Current Qvalue estimate
            
            current_q, imt = self._qmodel(state)
            current_q = tf.reduce_sum(current_q*onehot_act, axis=-1)
            
            q_loss = self.q_loss(target_q, current_q)
            imt_loss = self.imt_loss(onehot_act, imt)
            
            loss = q_loss + imt_loss + self._lam * tf.reduce_mean(tf.math.pow(imt, 2))
        
        grads = tape.gradient(loss, self._qmodel.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self._qmodel.trainable_variables))
        
        self._loss_tracker.update_state(loss)
        
        if self._iterations % self._update_count == 0:
            for param, tarparam in zip(self._qmodel.trainable_variables, self._target_qmodel.trainable_variables):
                tar_param.assign(self._tau*param + (1-self._tau)*tarparam)
        
        return {"loss":self._loss_tracker.result()}
    
    def test_step(self, data):
        state, target, _, _, _ = data
        target = tf.one_hot(target-1, depth=self._num_items)
        target = tf.cast(target, dtype=tf.int32)

        qvalue = self(state)
        topkitem = tf.math.top_k(qvalue, k=self._topk)[1]
        topkitem = tf.reduce_sum(tf.one_hot(topkitem, depth=self._num_items), axis=1)
        topkitem = tf.cast(topkitem, dtype=tf.int32)
        
        self._recall_tracker.update_state(target, topkitem)
        
        return {"recall":self._recall_tracker.result()}
    
    @property
    def metrics(self):
        return [self._loss_tracker, self._recall_tracker]

# %%
dataname="diginetica"
modelname = "BCQRec"
default_logdir = "/home/inoue/work/recs/"
log_dir =  os.path.join(default_logdir, "logs/%s/%s/"%(dataname, modelname)+datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
train = pickle.load(open(
    "/home/inoue/work/dataset/%s/derived/mdp_train.df"%dataname, "rb"
))

split_ind = int(len(train[0])*0.9)
data = pd.read_pickle("~/work/dataset/%s/derived/train.df"%dataname)
testdata = pd.read_pickle("~/work/dataset/%s/derived/test.df"%dataname)

num_items = max(data.itemId.max(), testdata.itemId.max())+1
seq_len = train[1].shape[1]

batch_size=500
train_data = tf.data.Dataset.from_tensor_slices(
    (train[1][:split_ind, :],
     train[2][:split_ind],
     train[3][:split_ind],
     train[4][:split_ind, :], 
     train[5][:split_ind].astype(np.float32))
).shuffle(len(train[0][:split_ind])).batch(batch_size)

valid_data = tf.data.Dataset.from_tensor_slices(
    (train[1][split_ind:, :],
     train[2][split_ind:],
     train[3][split_ind:],
     train[4][split_ind:, :], 
     train[5][split_ind:].astype(np.float32))
).shuffle(len(train[0][split_ind:])).batch(batch_size)

# %%
HP_EMB_DIM = hp.HParam("embed_dim", hp.Discrete([100, 150, 200]))
HP_HIDDEN_DIM = hp.HParam("hidden_dim", hp.Discrete([100, 150, 200]))
HP_THRESHOLD = hp.HParam("threshold", hp.Discrete([0.1, 0.3, 0.5]))
METRIC_RECALL = "recall"

update_count = 200
learning_rate=0.001
dropout_rate = 0.5
lam = 0.01
gamma = 1.


with tf.summary.create_file_writer(os.path.join(log_dir, "hparam_tuning")).as_default():
    hp.hparams_config(
        hparams=[HP_EMB_DIM, HP_HIDDEN_DIM, HP_THRESHOLD],
        metrics=[hp.Metric(METRIC_RECALL, display_name='Recall')],
      )

# %%
run_count = 0
for embed_dim in HP_EMB_DIM.domain.values:
    for hidden_dim in HP_EMB_DIM.domain.values:
        for threshold in HP_THRESHOLD.domain.values:
            hparams = {
                "embed_dim":embed_dim,
                "hidden_dim":hidden_dim,
                "threshold":threshold
            }
            run_count += 1
            
            print("-----Starting trial%d"%run_count)
            print(hparams)
            model = BCQRec(num_items, seq_len, hidden_dim, embed_dim, update_count=update_count)
            model.compile(optimizer=tfk.optimizers.Adam(learning_rate=learning_rate))
            model.build(input_shape=(1,seq_len))

            hist = model.fit(
                train_data, 
                epochs=100, 
                validation_data=valid_data,
                validation_freq=1,
                callbacks=[
                    tfk.callbacks.TensorBoard(log_dir=log_dir), 
                    tfk.callbacks.ModelCheckpoint(
                        filepath=os.path.join(default_logdir, "params/BCQRec/checkpoint_%d_%d_%f"%(embed_dim, hidden_dim, threshold)),
                        save_weights_only=True,
                        monitor="val_recall",
                        mode="max",
                        save_best_only=True
                    ),
                    tfk.callbacks.EarlyStopping(
                        monitor="val_recall",
                        min_delta=1e-4,
                        patience=3,
                        mode="max",
                        verbose=1)])
            
            with tf.summary.create_file_writer(os.path.join(log_dir, "hparam_tuning")).as_default():
                hp.hparams(hparams)
                tf.summary.scalar(METRIC_RECALL, hist.history["val_recall"][-1], step=run_count)
# Out:
# -----Starting trial1
# {'embed_dim': 100, 'hidden_dim': 100, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 57s 73ms/step - loss: 10.0905 - val_recall: 0.0127
# Epoch 2/100
# 646/646 [==============================] - 51s 77ms/step - loss: 9.3680 - val_recall: 0.0454
# Epoch 3/100
# 646/646 [==============================] - 51s 77ms/step - loss: 8.5925 - val_recall: 0.1190
# Epoch 4/100
# 646/646 [==============================] - 50s 76ms/step - loss: 7.6799 - val_recall: 0.2026
# Epoch 5/100
# 646/646 [==============================] - 50s 76ms/step - loss: 6.9105 - val_recall: 0.2619
# Epoch 6/100
# 646/646 [==============================] - 50s 76ms/step - loss: 6.3296 - val_recall: 0.3004
# Epoch 7/100
# 646/646 [==============================] - 50s 75ms/step - loss: 5.8778 - val_recall: 0.3231
# Epoch 8/100
# 646/646 [==============================] - 46s 69ms/step - loss: 5.5047 - val_recall: 0.3406
# Epoch 9/100
# 646/646 [==============================] - 50s 76ms/step - loss: 5.1804 - val_recall: 0.3493
# Epoch 10/100
# 646/646 [==============================] - 46s 70ms/step - loss: 4.8873 - val_recall: 0.3571
# Epoch 11/100
# 646/646 [==============================] - 51s 77ms/step - loss: 4.6201 - val_recall: 0.3590
# Epoch 12/100
# 646/646 [==============================] - 50s 76ms/step - loss: 4.3727 - val_recall: 0.3601
# Epoch 13/100
# 646/646 [==============================] - 48s 72ms/step - loss: 4.1450 - val_recall: 0.3588
# Epoch 14/100
# 646/646 [==============================] - 48s 72ms/step - loss: 3.9369 - val_recall: 0.3594
# Epoch 15/100
# 646/646 [==============================] - 48s 72ms/step - loss: 3.7448 - val_recall: 0.3584
# Epoch 15: early stopping
# -----Starting trial2
# {'embed_dim': 100, 'hidden_dim': 100, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 58s 78ms/step - loss: 10.0883 - val_recall: 0.0136
# Epoch 2/100
# 646/646 [==============================] - 50s 76ms/step - loss: 9.3791 - val_recall: 0.0398
# Epoch 3/100
# 646/646 [==============================] - 50s 76ms/step - loss: 8.6402 - val_recall: 0.1212
# Epoch 4/100
# 646/646 [==============================] - 50s 76ms/step - loss: 7.6974 - val_recall: 0.2028
# Epoch 5/100
# 646/646 [==============================] - 50s 75ms/step - loss: 6.9026 - val_recall: 0.2602
# Epoch 6/100
# 646/646 [==============================] - 50s 76ms/step - loss: 6.3193 - val_recall: 0.2997
# Epoch 7/100
# 646/646 [==============================] - 51s 77ms/step - loss: 5.8669 - val_recall: 0.3210
# Epoch 8/100
# 646/646 [==============================] - 50s 76ms/step - loss: 5.4930 - val_recall: 0.3362
# Epoch 9/100
# 646/646 [==============================] - 51s 77ms/step - loss: 5.1677 - val_recall: 0.3484
# Epoch 10/100
# 646/646 [==============================] - 50s 77ms/step - loss: 4.8754 - val_recall: 0.3544
# Epoch 11/100
# 646/646 [==============================] - 51s 77ms/step - loss: 4.6096 - val_recall: 0.3579
# Epoch 12/100
# 646/646 [==============================] - 49s 74ms/step - loss: 4.3642 - val_recall: 0.3575
# Epoch 13/100
# 646/646 [==============================] - 48s 73ms/step - loss: 4.1378 - val_recall: 0.3578
# Epoch 14/100
# 646/646 [==============================] - 48s 73ms/step - loss: 3.9306 - val_recall: 0.3575
# Epoch 14: early stopping
# -----Starting trial3
# {'embed_dim': 100, 'hidden_dim': 100, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 59s 78ms/step - loss: 10.0920 - val_recall: 0.0143
# Epoch 2/100
# 646/646 [==============================] - 50s 76ms/step - loss: 9.3811 - val_recall: 0.0442
# Epoch 3/100
# 646/646 [==============================] - 50s 76ms/step - loss: 8.6022 - val_recall: 0.1173
# Epoch 4/100
# 646/646 [==============================] - 48s 73ms/step - loss: 7.7067 - val_recall: 0.1960
# Epoch 5/100
# 646/646 [==============================] - 50s 76ms/step - loss: 6.9760 - val_recall: 0.2506
# Epoch 6/100
# 646/646 [==============================] - 50s 76ms/step - loss: 6.4165 - val_recall: 0.2901
# Epoch 7/100
# 646/646 [==============================] - 50s 76ms/step - loss: 5.9702 - val_recall: 0.3169
# Epoch 8/100
# 646/646 [==============================] - 50s 75ms/step - loss: 5.5931 - val_recall: 0.3335
# Epoch 9/100
# 646/646 [==============================] - 49s 75ms/step - loss: 5.2622 - val_recall: 0.3435
# Epoch 10/100
# 646/646 [==============================] - 50s 75ms/step - loss: 4.9632 - val_recall: 0.3507
# Epoch 11/100
# 646/646 [==============================] - 50s 76ms/step - loss: 4.6902 - val_recall: 0.3540
# Epoch 12/100
# 646/646 [==============================] - 50s 75ms/step - loss: 4.4382 - val_recall: 0.3558
# Epoch 13/100
# 646/646 [==============================] - 46s 70ms/step - loss: 4.2052 - val_recall: 0.3553
# Epoch 14/100
# 646/646 [==============================] - 48s 73ms/step - loss: 3.9914 - val_recall: 0.3555
# Epoch 15/100
# 646/646 [==============================] - 48s 72ms/step - loss: 3.7969 - val_recall: 0.3532
# Epoch 15: early stopping
# -----Starting trial4
# {'embed_dim': 100, 'hidden_dim': 150, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 60s 79ms/step - loss: 10.0564 - val_recall: 0.0171
# Epoch 2/100
# 646/646 [==============================] - 51s 78ms/step - loss: 9.2640 - val_recall: 0.0643
# Epoch 3/100
# 646/646 [==============================] - 53s 80ms/step - loss: 8.3054 - val_recall: 0.1621
# Epoch 4/100
# 646/646 [==============================] - 47s 72ms/step - loss: 7.2826 - val_recall: 0.2397
# Epoch 5/100
# 646/646 [==============================] - 46s 69ms/step - loss: 6.4922 - val_recall: 0.2931
# Epoch 6/100
# 646/646 [==============================] - 48s 73ms/step - loss: 5.8636 - val_recall: 0.3260
# Epoch 7/100
# 646/646 [==============================] - 47s 71ms/step - loss: 5.3465 - val_recall: 0.3443
# Epoch 8/100
# 646/646 [==============================] - 45s 69ms/step - loss: 4.9010 - val_recall: 0.3496
# Epoch 9/100
# 646/646 [==============================] - 52s 78ms/step - loss: 4.5070 - val_recall: 0.3544
# Epoch 10/100
# 646/646 [==============================] - 48s 72ms/step - loss: 4.1565 - val_recall: 0.3546
# Epoch 11/100
# 646/646 [==============================] - 43s 65ms/step - loss: 3.8466 - val_recall: 0.3528
# Epoch 12/100
# 646/646 [==============================] - 44s 67ms/step - loss: 3.5734 - val_recall: 0.3506
# Epoch 13/100
# 646/646 [==============================] - 42s 64ms/step - loss: 3.3311 - val_recall: 0.3497
# Epoch 13: early stopping
# -----Starting trial5
# {'embed_dim': 100, 'hidden_dim': 150, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 61s 82ms/step - loss: 10.0580 - val_recall: 0.0171
# Epoch 2/100
# 646/646 [==============================] - 53s 80ms/step - loss: 9.2575 - val_recall: 0.0646
# Epoch 3/100
# 646/646 [==============================] - 53s 80ms/step - loss: 8.3070 - val_recall: 0.1609
# Epoch 4/100
# 646/646 [==============================] - 53s 81ms/step - loss: 7.2982 - val_recall: 0.2381
# Epoch 5/100
# 646/646 [==============================] - 53s 80ms/step - loss: 6.4961 - val_recall: 0.2926
# Epoch 6/100
# 646/646 [==============================] - 53s 80ms/step - loss: 5.8699 - val_recall: 0.3237
# Epoch 7/100
# 646/646 [==============================] - 47s 71ms/step - loss: 5.3594 - val_recall: 0.3414
# Epoch 8/100
# 646/646 [==============================] - 48s 72ms/step - loss: 4.9232 - val_recall: 0.3498
# Epoch 9/100
# 646/646 [==============================] - 45s 68ms/step - loss: 4.5358 - val_recall: 0.3545
# Epoch 10/100
# 646/646 [==============================] - 41s 61ms/step - loss: 4.1898 - val_recall: 0.3530
# Epoch 11/100
# 646/646 [==============================] - 41s 61ms/step - loss: 3.8787 - val_recall: 0.3533
# Epoch 12/100
# 646/646 [==============================] - 42s 63ms/step - loss: 3.6034 - val_recall: 0.3513
# Epoch 12: early stopping
# -----Starting trial6
# {'embed_dim': 100, 'hidden_dim': 150, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 55s 69ms/step - loss: 10.0555 - val_recall: 0.0165
# Epoch 2/100
# 646/646 [==============================] - 45s 67ms/step - loss: 9.2569 - val_recall: 0.0571
# Epoch 3/100
# 646/646 [==============================] - 44s 67ms/step - loss: 8.3326 - val_recall: 0.1607
# Epoch 4/100
# 646/646 [==============================] - 44s 67ms/step - loss: 7.2868 - val_recall: 0.2420
# Epoch 5/100
# 646/646 [==============================] - 52s 79ms/step - loss: 6.4676 - val_recall: 0.2960
# Epoch 6/100
# 646/646 [==============================] - 51s 78ms/step - loss: 5.8394 - val_recall: 0.3237
# Epoch 7/100
# 646/646 [==============================] - 52s 79ms/step - loss: 5.3342 - val_recall: 0.3409
# Epoch 8/100
# 646/646 [==============================] - 53s 80ms/step - loss: 4.9043 - val_recall: 0.3482
# Epoch 9/100
# 646/646 [==============================] - 46s 69ms/step - loss: 4.5265 - val_recall: 0.3528
# Epoch 10/100
# 646/646 [==============================] - 46s 70ms/step - loss: 4.1884 - val_recall: 0.3524
# Epoch 11/100
# 646/646 [==============================] - 43s 65ms/step - loss: 3.8843 - val_recall: 0.3518
# Epoch 12/100
# 646/646 [==============================] - 47s 72ms/step - loss: 3.6137 - val_recall: 0.3497
# Epoch 12: early stopping
# -----Starting trial7
# {'embed_dim': 100, 'hidden_dim': 200, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 63s 84ms/step - loss: 10.0282 - val_recall: 0.0191
# Epoch 2/100
# 646/646 [==============================] - 54s 82ms/step - loss: 9.1602 - val_recall: 0.0748
# Epoch 3/100
# 646/646 [==============================] - 54s 82ms/step - loss: 8.1331 - val_recall: 0.1816
# Epoch 4/100
# 646/646 [==============================] - 54s 81ms/step - loss: 7.0642 - val_recall: 0.2678
# Epoch 5/100
# 646/646 [==============================] - 55s 83ms/step - loss: 6.1807 - val_recall: 0.3192
# Epoch 6/100
# 646/646 [==============================] - 53s 81ms/step - loss: 5.4726 - val_recall: 0.3449
# Epoch 7/100
# 646/646 [==============================] - 53s 79ms/step - loss: 4.8906 - val_recall: 0.3538
# Epoch 8/100
# 646/646 [==============================] - 53s 80ms/step - loss: 4.3958 - val_recall: 0.3544
# Epoch 9/100
# 646/646 [==============================] - 46s 69ms/step - loss: 3.9686 - val_recall: 0.3522
# Epoch 10/100
# 646/646 [==============================] - 41s 61ms/step - loss: 3.6086 - val_recall: 0.3498
# Epoch 11/100
# 646/646 [==============================] - 41s 61ms/step - loss: 3.3018 - val_recall: 0.3461
# Epoch 11: early stopping
# -----Starting trial8
# {'embed_dim': 100, 'hidden_dim': 200, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 55s 71ms/step - loss: 10.0263 - val_recall: 0.0202
# Epoch 2/100
# 646/646 [==============================] - 45s 67ms/step - loss: 9.1740 - val_recall: 0.0698
# Epoch 3/100
# 646/646 [==============================] - 45s 67ms/step - loss: 8.1749 - val_recall: 0.1763
# Epoch 4/100
# 646/646 [==============================] - 45s 68ms/step - loss: 7.1052 - val_recall: 0.2622
# Epoch 5/100
# 646/646 [==============================] - 45s 68ms/step - loss: 6.2421 - val_recall: 0.3135
# Epoch 6/100
# 646/646 [==============================] - 50s 75ms/step - loss: 5.5401 - val_recall: 0.3408
# Epoch 7/100
# 646/646 [==============================] - 53s 81ms/step - loss: 4.9592 - val_recall: 0.3488
# Epoch 8/100
# 646/646 [==============================] - 54s 82ms/step - loss: 4.4637 - val_recall: 0.3529
# Epoch 9/100
# 646/646 [==============================] - 54s 81ms/step - loss: 4.0334 - val_recall: 0.3531
# Epoch 10/100
# 646/646 [==============================] - 50s 76ms/step - loss: 3.6643 - val_recall: 0.3489
# Epoch 11/100
# 646/646 [==============================] - 50s 76ms/step - loss: 3.3494 - val_recall: 0.3459
# Epoch 12/100
# 646/646 [==============================] - 50s 75ms/step - loss: 3.0856 - val_recall: 0.3413
# Epoch 12: early stopping
# -----Starting trial9
# {'embed_dim': 100, 'hidden_dim': 200, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 63s 85ms/step - loss: 10.0273 - val_recall: 0.0199
# Epoch 2/100
# 646/646 [==============================] - 55s 83ms/step - loss: 9.1635 - val_recall: 0.0780
# Epoch 3/100
# 646/646 [==============================] - 54s 82ms/step - loss: 8.1108 - val_recall: 0.1814
# Epoch 4/100
# 646/646 [==============================] - 54s 82ms/step - loss: 7.0492 - val_recall: 0.2706
# Epoch 5/100
# 646/646 [==============================] - 54s 82ms/step - loss: 6.1800 - val_recall: 0.3234
# Epoch 6/100
# 646/646 [==============================] - 54s 82ms/step - loss: 5.4759 - val_recall: 0.3442
# Epoch 7/100
# 646/646 [==============================] - 54s 82ms/step - loss: 4.8974 - val_recall: 0.3535
# Epoch 8/100
# 646/646 [==============================] - 54s 82ms/step - loss: 4.4030 - val_recall: 0.3564
# Epoch 9/100
# 646/646 [==============================] - 50s 76ms/step - loss: 3.9757 - val_recall: 0.3533
# Epoch 10/100
# 646/646 [==============================] - 51s 77ms/step - loss: 3.6134 - val_recall: 0.3492
# Epoch 11/100
# 646/646 [==============================] - 50s 76ms/step - loss: 3.3050 - val_recall: 0.3481
# Epoch 11: early stopping
# -----Starting trial10
# {'embed_dim': 150, 'hidden_dim': 100, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 60s 80ms/step - loss: 10.0831 - val_recall: 0.0136
# Epoch 2/100
# 646/646 [==============================] - 51s 77ms/step - loss: 9.3490 - val_recall: 0.0538
# Epoch 3/100
# 646/646 [==============================] - 51s 77ms/step - loss: 8.4464 - val_recall: 0.1456
# Epoch 4/100
# 646/646 [==============================] - 51s 77ms/step - loss: 7.4652 - val_recall: 0.2268
# Epoch 5/100
# 646/646 [==============================] - 51s 78ms/step - loss: 6.7169 - val_recall: 0.2809
# Epoch 6/100
# 646/646 [==============================] - 51s 78ms/step - loss: 6.1478 - val_recall: 0.3161
# Epoch 7/100
# 646/646 [==============================] - 51s 78ms/step - loss: 5.6952 - val_recall: 0.3377
# Epoch 8/100
# 646/646 [==============================] - 51s 77ms/step - loss: 5.3133 - val_recall: 0.3496
# Epoch 9/100
# 646/646 [==============================] - 51s 77ms/step - loss: 4.9773 - val_recall: 0.3574
# Epoch 10/100
# 646/646 [==============================] - 51s 77ms/step - loss: 4.6730 - val_recall: 0.3650
# Epoch 11/100
# 646/646 [==============================] - 48s 73ms/step - loss: 4.3974 - val_recall: 0.3642
# Epoch 12/100
# 646/646 [==============================] - 48s 73ms/step - loss: 4.1441 - val_recall: 0.3646
# Epoch 13/100
# 646/646 [==============================] - 49s 74ms/step - loss: 3.9150 - val_recall: 0.3638
# Epoch 13: early stopping
# -----Starting trial11
# {'embed_dim': 150, 'hidden_dim': 100, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 60s 80ms/step - loss: 10.0845 - val_recall: 0.0133
# Epoch 2/100
# 646/646 [==============================] - 51s 77ms/step - loss: 9.3429 - val_recall: 0.0536
# Epoch 3/100
# 646/646 [==============================] - 52s 78ms/step - loss: 8.4664 - val_recall: 0.1414
# Epoch 4/100
# 646/646 [==============================] - 52s 79ms/step - loss: 7.4888 - val_recall: 0.2261
# Epoch 5/100
# 646/646 [==============================] - 52s 78ms/step - loss: 6.7112 - val_recall: 0.2814
# Epoch 6/100
# 646/646 [==============================] - 52s 78ms/step - loss: 6.1207 - val_recall: 0.3171
# Epoch 7/100
# 646/646 [==============================] - 51s 77ms/step - loss: 5.6550 - val_recall: 0.3405
# Epoch 8/100
# 646/646 [==============================] - 52s 79ms/step - loss: 5.2655 - val_recall: 0.3523
# Epoch 9/100
# 646/646 [==============================] - 51s 78ms/step - loss: 4.9251 - val_recall: 0.3587
# Epoch 10/100
# 646/646 [==============================] - 52s 79ms/step - loss: 4.6185 - val_recall: 0.3627
# Epoch 11/100
# 646/646 [==============================] - 51s 78ms/step - loss: 4.3410 - val_recall: 0.3641
# Epoch 12/100
# 646/646 [==============================] - 49s 74ms/step - loss: 4.0903 - val_recall: 0.3611
# Epoch 13/100
# 646/646 [==============================] - 49s 74ms/step - loss: 3.8622 - val_recall: 0.3641
# Epoch 14/100
# 646/646 [==============================] - 48s 73ms/step - loss: 3.6583 - val_recall: 0.3600
# Epoch 14: early stopping
# -----Starting trial12
# {'embed_dim': 150, 'hidden_dim': 100, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 60s 81ms/step - loss: 10.0789 - val_recall: 0.0140
# Epoch 2/100
# 646/646 [==============================] - 49s 74ms/step - loss: 9.3298 - val_recall: 0.0508
# Epoch 3/100
# 646/646 [==============================] - 46s 69ms/step - loss: 8.4657 - val_recall: 0.1415
# Epoch 4/100
# 646/646 [==============================] - 45s 69ms/step - loss: 7.5073 - val_recall: 0.2219
# Epoch 5/100
# 646/646 [==============================] - 46s 69ms/step - loss: 6.7515 - val_recall: 0.2732
# Epoch 6/100
# 646/646 [==============================] - 45s 67ms/step - loss: 6.1791 - val_recall: 0.3107
# Epoch 7/100
# 646/646 [==============================] - 45s 68ms/step - loss: 5.7218 - val_recall: 0.3353
# Epoch 8/100
# 646/646 [==============================] - 45s 67ms/step - loss: 5.3342 - val_recall: 0.3495
# Epoch 9/100
# 646/646 [==============================] - 45s 67ms/step - loss: 4.9948 - val_recall: 0.3583
# Epoch 10/100
# 646/646 [==============================] - 50s 75ms/step - loss: 4.6885 - val_recall: 0.3597
# Epoch 11/100
# 646/646 [==============================] - 51s 77ms/step - loss: 4.4097 - val_recall: 0.3621
# Epoch 12/100
# 646/646 [==============================] - 52s 78ms/step - loss: 4.1558 - val_recall: 0.3656
# Epoch 13/100
# 646/646 [==============================] - 43s 65ms/step - loss: 3.9236 - val_recall: 0.3626
# Epoch 14/100
# 646/646 [==============================] - 45s 69ms/step - loss: 3.7163 - val_recall: 0.3621
# Epoch 15/100
# 646/646 [==============================] - 50s 76ms/step - loss: 3.5287 - val_recall: 0.3613
# Epoch 15: early stopping
# -----Starting trial13
# {'embed_dim': 150, 'hidden_dim': 150, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 63s 81ms/step - loss: 10.0447 - val_recall: 0.0177
# Epoch 2/100
# 646/646 [==============================] - 55s 84ms/step - loss: 9.1905 - val_recall: 0.0732
# Epoch 3/100
# 646/646 [==============================] - 59s 89ms/step - loss: 8.1403 - val_recall: 0.1877
# Epoch 4/100
# 646/646 [==============================] - 47s 72ms/step - loss: 7.0523 - val_recall: 0.2731
# Epoch 5/100
# 646/646 [==============================] - 68s 103ms/step - loss: 6.2093 - val_recall: 0.3250
# Epoch 6/100
# 646/646 [==============================] - 50s 75ms/step - loss: 5.5596 - val_recall: 0.3522
# Epoch 7/100
# 646/646 [==============================] - 86s 132ms/step - loss: 5.0373 - val_recall: 0.3622
# Epoch 8/100
# 646/646 [==============================] - 71s 108ms/step - loss: 4.5921 - val_recall: 0.3663
# Epoch 9/100
# 646/646 [==============================] - 83s 127ms/step - loss: 4.2011 - val_recall: 0.3659
# Epoch 10/100
# 646/646 [==============================] - 46s 69ms/step - loss: 3.8562 - val_recall: 0.3647
# Epoch 11/100
# 646/646 [==============================] - 97s 149ms/step - loss: 3.5558 - val_recall: 0.3603
# Epoch 11: early stopping
# -----Starting trial14
# {'embed_dim': 150, 'hidden_dim': 150, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 63s 81ms/step - loss: 10.0442 - val_recall: 0.0183
# Epoch 2/100
# 646/646 [==============================] - 110s 169ms/step - loss: 9.1927 - val_recall: 0.0733
# Epoch 3/100
# 646/646 [==============================] - 74s 113ms/step - loss: 8.1202 - val_recall: 0.1897
# Epoch 4/100
# 646/646 [==============================] - 70s 106ms/step - loss: 7.0437 - val_recall: 0.2704
# Epoch 5/100
# 646/646 [==============================] - 106s 163ms/step - loss: 6.2163 - val_recall: 0.3222
# Epoch 6/100
# 646/646 [==============================] - 65s 99ms/step - loss: 5.5824 - val_recall: 0.3446
# Epoch 7/100
# 646/646 [==============================] - 99s 151ms/step - loss: 5.0711 - val_recall: 0.3573
# Epoch 8/100
# 646/646 [==============================] - 50s 76ms/step - loss: 4.2437 - val_recall: 0.3643
# Epoch 10/100
# 646/646 [==============================] - 116s 178ms/step - loss: 3.8993 - val_recall: 0.3593
# Epoch 11/100
# 646/646 [==============================] - 65s 99ms/step - loss: 3.5970 - val_recall: 0.3570
# Epoch 12/100
# 646/646 [==============================] - 73s 111ms/step - loss: 3.3330 - val_recall: 0.3556
# Epoch 12: early stopping
# -----Starting trial15
# {'embed_dim': 150, 'hidden_dim': 150, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 132s 188ms/step - loss: 10.0520 - val_recall: 0.0167
# Epoch 2/100
# 323/646 [==============>...............] - ETA: 46s - loss: 9.3645
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 646/646 [==============================] - 120s 183ms/step - loss: 3.9127 - val_recall: 0.3616
# Epoch 11/100
# 646/646 [==============================] - 68s 103ms/step - loss: 3.6034 - val_recall: 0.3592
# Epoch 12/100
# 646/646 [==============================] - 108s 166ms/step - loss: 3.3355 - val_recall: 0.3560
# Epoch 12: early stopping
# -----Starting trial16
# {'embed_dim': 150, 'hidden_dim': 200, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 132s 188ms/step - loss: 10.0183 - val_recall: 0.0212
# Epoch 2/100
# 646/646 [==============================] - 73s 111ms/step - loss: 9.0683 - val_recall: 0.0963
# Epoch 3/100
# 113/646 [====>.........................] - ETA: 41s - loss: 8.2034
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 646/646 [==============================] - 130s 199ms/step - loss: 6.7359 - val_recall: 0.3049
# Epoch 5/100
# 646/646 [==============================] - 102s 156ms/step - loss: 5.8634 - val_recall: 0.3432
# Epoch 6/100
# 646/646 [==============================] - 58s 88ms/step - loss: 5.1785 - val_recall: 0.3574
# Epoch 7/100
# 646/646 [==============================] - 138s 213ms/step - loss: 4.6130 - val_recall: 0.3663
# Epoch 8/100
# 646/646 [==============================] - 117s 179ms/step - loss: 4.1324 - val_recall: 0.3609
# Epoch 9/100
# 646/646 [==============================] - 77s 117ms/step - loss: 3.7210 - val_recall: 0.3623
# Epoch 10/100
# 646/646 [==============================] - 63s 95ms/step - loss: 3.3757 - val_recall: 0.3567
# Epoch 10: early stopping
# -----Starting trial17
# {'embed_dim': 150, 'hidden_dim': 200, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 153s 222ms/step - loss: 10.0212 - val_recall: 0.0196
# Epoch 2/100
# 646/646 [==============================] - 107s 164ms/step - loss: 9.0965 - val_recall: 0.0912
# Epoch 3/100
# 646/646 [==============================] - 62s 95ms/step - loss: 7.9289 - val_recall: 0.2210
# Epoch 4/100
# 646/646 [==============================] - 148s 227ms/step - loss: 6.7769 - val_recall: 0.3032
# Epoch 5/100
# 646/646 [==============================] - 128s 196ms/step - loss: 5.8829 - val_recall: 0.3429
# Epoch 6/100
# 646/646 [==============================] - 75s 115ms/step - loss: 5.1834 - val_recall: 0.3598
# Epoch 7/100
# 646/646 [==============================] - 80s 122ms/step - loss: 4.6037 - val_recall: 0.3641
# Epoch 8/100
# 646/646 [==============================] - 140s 216ms/step - loss: 4.1117 - val_recall: 0.3638
# Epoch 9/100
# 646/646 [==============================] - 118s 180ms/step - loss: 3.6950 - val_recall: 0.3591
# Epoch 10/100
# 646/646 [==============================] - 75s 115ms/step - loss: 3.3419 - val_recall: 0.3548
# Epoch 10: early stopping
# -----Starting trial18
# {'embed_dim': 150, 'hidden_dim': 200, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 98s 135ms/step - loss: 10.0190 - val_recall: 0.0219
# Epoch 2/100
# 646/646 [==============================] - 147s 226ms/step - loss: 9.0638 - val_recall: 0.0974
# Epoch 3/100
# 646/646 [==============================] - 124s 190ms/step - loss: 7.8759 - val_recall: 0.2182
# Epoch 4/100
# 646/646 [==============================] - 69s 105ms/step - loss: 6.7540 - val_recall: 0.3034
# Epoch 5/100
# 646/646 [==============================] - 88s 135ms/step - loss: 5.8672 - val_recall: 0.3431
# Epoch 6/100
# 646/646 [==============================] - 149s 229ms/step - loss: 5.1646 - val_recall: 0.3582
# Epoch 7/100
# 646/646 [==============================] - 129s 197ms/step - loss: 4.5830 - val_recall: 0.3621
# Epoch 8/100
# 646/646 [==============================] - 78s 119ms/step - loss: 4.0883 - val_recall: 0.3613
# Epoch 9/100
# 646/646 [==============================] - 68s 104ms/step - loss: 3.6707 - val_recall: 0.3579
# Epoch 10/100
# 646/646 [==============================] - 152s 234ms/step - loss: 3.3209 - val_recall: 0.3545
# Epoch 10: early stopping
# -----Starting trial19
# {'embed_dim': 200, 'hidden_dim': 100, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 148s 213ms/step - loss: 10.0746 - val_recall: 0.0147
# Epoch 2/100
# 646/646 [==============================] - 94s 144ms/step - loss: 9.3014 - val_recall: 0.0607
# Epoch 3/100
# 646/646 [==============================] - 62s 94ms/step - loss: 8.3291 - val_recall: 0.1649
# Epoch 4/100
# 646/646 [==============================] - 156s 240ms/step - loss: 7.3102 - val_recall: 0.2454
# Epoch 5/100
# 646/646 [==============================] - 138s 212ms/step - loss: 6.5320 - val_recall: 0.3010
# Epoch 6/100
# 646/646 [==============================] - 118s 181ms/step - loss: 5.9492 - val_recall: 0.3345
# Epoch 7/100
# 646/646 [==============================] - 61s 93ms/step - loss: 5.4896 - val_recall: 0.3513
# Epoch 8/100
# 646/646 [==============================] - 142s 218ms/step - loss: 5.1036 - val_recall: 0.3630
# Epoch 9/100
# 646/646 [==============================] - 148s 227ms/step - loss: 4.7640 - val_recall: 0.3661
# Epoch 10/100
# 646/646 [==============================] - 107s 163ms/step - loss: 4.4588 - val_recall: 0.3705
# Epoch 11/100
# 646/646 [==============================] - 60s 91ms/step - loss: 4.1846 - val_recall: 0.3710
# Epoch 12/100
# 646/646 [==============================] - 147s 226ms/step - loss: 3.9375 - val_recall: 0.3710
# Epoch 13/100
# 646/646 [==============================] - 144s 221ms/step - loss: 3.7161 - val_recall: 0.3682
# Epoch 14/100
# 646/646 [==============================] - 108s 165ms/step - loss: 3.5183 - val_recall: 0.3637
# Epoch 14: early stopping
# -----Starting trial20
# {'embed_dim': 200, 'hidden_dim': 100, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 72s 95ms/step - loss: 10.0725 - val_recall: 0.0161
# Epoch 2/100
# 646/646 [==============================] - 144s 222ms/step - loss: 9.2979 - val_recall: 0.0558
# Epoch 3/100
# 646/646 [==============================] - 142s 218ms/step - loss: 8.3361 - val_recall: 0.1675
# Epoch 4/100
# 646/646 [==============================] - 115s 176ms/step - loss: 7.2813 - val_recall: 0.2514
# Epoch 5/100
# 646/646 [==============================] - 67s 101ms/step - loss: 6.5012 - val_recall: 0.3052
# Epoch 6/100
# 646/646 [==============================] - 148s 227ms/step - loss: 5.9333 - val_recall: 0.3350
# Epoch 7/100
# 646/646 [==============================] - 140s 216ms/step - loss: 5.4862 - val_recall: 0.3541
# Epoch 8/100
# 646/646 [==============================] - 126s 194ms/step - loss: 5.1067 - val_recall: 0.3624
# Epoch 9/100
# 646/646 [==============================] - 74s 113ms/step - loss: 4.7730 - val_recall: 0.3679
# Epoch 10/100
# 646/646 [==============================] - 68s 103ms/step - loss: 4.4727 - val_recall: 0.3692
# Epoch 11/100
# 646/646 [==============================] - 146s 225ms/step - loss: 4.1996 - val_recall: 0.3701
# Epoch 12/100
# 646/646 [==============================] - 137s 210ms/step - loss: 3.9534 - val_recall: 0.3682
# Epoch 13/100
# 646/646 [==============================] - 116s 178ms/step - loss: 3.7332 - val_recall: 0.3665
# Epoch 14/100
# 646/646 [==============================] - 64s 97ms/step - loss: 3.5357 - val_recall: 0.3635
# Epoch 14: early stopping
# -----Starting trial21
# {'embed_dim': 200, 'hidden_dim': 100, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 172s 252ms/step - loss: 10.0729 - val_recall: 0.0139
# Epoch 2/100
# 646/646 [==============================] - 165s 253ms/step - loss: 9.3017 - val_recall: 0.0641
# Epoch 3/100
# 646/646 [==============================] - 141s 216ms/step - loss: 8.2855 - val_recall: 0.1749
# Epoch 4/100
# 646/646 [==============================] - 69s 104ms/step - loss: 7.2651 - val_recall: 0.2519
# Epoch 5/100
# 646/646 [==============================] - 56s 85ms/step - loss: 6.5192 - val_recall: 0.2995
# Epoch 6/100
# 646/646 [==============================] - 54s 81ms/step - loss: 5.9615 - val_recall: 0.3279
# Epoch 7/100
# 646/646 [==============================] - 63s 95ms/step - loss: 5.5180 - val_recall: 0.3471
# Epoch 8/100
# 646/646 [==============================] - 59s 89ms/step - loss: 5.1436 - val_recall: 0.3573
# Epoch 9/100
# 646/646 [==============================] - 67s 103ms/step - loss: 4.8103 - val_recall: 0.3656
# Epoch 10/100
# 646/646 [==============================] - 78s 119ms/step - loss: 4.5087 - val_recall: 0.3651
# Epoch 11/100
# 646/646 [==============================] - 76s 117ms/step - loss: 4.2364 - val_recall: 0.3678
# Epoch 12/100
# 646/646 [==============================] - 75s 115ms/step - loss: 3.9887 - val_recall: 0.3682
# Epoch 13/100
# 646/646 [==============================] - 71s 107ms/step - loss: 3.7658 - val_recall: 0.3677
# Epoch 14/100
# 646/646 [==============================] - 74s 113ms/step - loss: 3.5672 - val_recall: 0.3657
# Epoch 15/100
# 646/646 [==============================] - 74s 112ms/step - loss: 3.3894 - val_recall: 0.3649
# Epoch 15: early stopping
# -----Starting trial22
# {'embed_dim': 200, 'hidden_dim': 150, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 92s 127ms/step - loss: 10.0381 - val_recall: 0.0210
# Epoch 2/100
# 646/646 [==============================] - 82s 125ms/step - loss: 9.1273 - val_recall: 0.0914
# Epoch 3/100
# 646/646 [==============================] - 80s 122ms/step - loss: 7.9396 - val_recall: 0.2136
# Epoch 4/100
# 646/646 [==============================] - 74s 113ms/step - loss: 6.8235 - val_recall: 0.2985
# Epoch 5/100
# 646/646 [==============================] - 73s 112ms/step - loss: 5.9904 - val_recall: 0.3414
# Epoch 6/100
# 646/646 [==============================] - 88s 135ms/step - loss: 5.3587 - val_recall: 0.3591
# Epoch 7/100
# 646/646 [==============================] - 95s 146ms/step - loss: 4.8412 - val_recall: 0.3686
# Epoch 8/100
# 646/646 [==============================] - 85s 131ms/step - loss: 4.3996 - val_recall: 0.3707
# Epoch 9/100
# 646/646 [==============================] - 73s 112ms/step - loss: 4.0105 - val_recall: 0.3708
# Epoch 10/100
# 646/646 [==============================] - 83s 127ms/step - loss: 3.6706 - val_recall: 0.3659
# Epoch 11/100
# 646/646 [==============================] - 106s 162ms/step - loss: 3.3776 - val_recall: 0.3646
# Epoch 11: early stopping
# -----Starting trial23
# {'embed_dim': 200, 'hidden_dim': 150, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 117s 165ms/step - loss: 10.0338 - val_recall: 0.0204
# Epoch 2/100
# 646/646 [==============================] - 88s 134ms/step - loss: 9.1145 - val_recall: 0.0915
# Epoch 3/100
# 646/646 [==============================] - 74s 113ms/step - loss: 7.9350 - val_recall: 0.2201
# Epoch 4/100
# 646/646 [==============================] - 109s 167ms/step - loss: 6.7856 - val_recall: 0.3082
# Epoch 5/100
# 646/646 [==============================] - 89s 135ms/step - loss: 5.9189 - val_recall: 0.3476
# Epoch 6/100
# 646/646 [==============================] - 71s 108ms/step - loss: 5.2653 - val_recall: 0.3650
# Epoch 7/100
# 646/646 [==============================] - 108s 165ms/step - loss: 4.7420 - val_recall: 0.3738
# Epoch 8/100
# 646/646 [==============================] - 67s 102ms/step - loss: 4.2996 - val_recall: 0.3736
# Epoch 9/100
# 646/646 [==============================] - 93s 143ms/step - loss: 3.9156 - val_recall: 0.3719
# Epoch 10/100
# 646/646 [==============================] - 75s 114ms/step - loss: 3.5858 - val_recall: 0.3679
# Epoch 10: early stopping
# -----Starting trial24
# {'embed_dim': 200, 'hidden_dim': 150, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 91s 125ms/step - loss: 10.0360 - val_recall: 0.0191
# Epoch 2/100
# 646/646 [==============================] - 47s 70ms/step - loss: 9.1134 - val_recall: 0.0954
# Epoch 3/100
# 646/646 [==============================] - 48s 73ms/step - loss: 7.9042 - val_recall: 0.2144
# Epoch 4/100
# 646/646 [==============================] - 49s 75ms/step - loss: 6.8226 - val_recall: 0.2937
# Epoch 5/100
# 646/646 [==============================] - 50s 76ms/step - loss: 6.0126 - val_recall: 0.3380
# Epoch 6/100
# 646/646 [==============================] - 51s 78ms/step - loss: 5.3869 - val_recall: 0.3579
# Epoch 7/100
# 646/646 [==============================] - 52s 79ms/step - loss: 4.8727 - val_recall: 0.3661
# Epoch 8/100
# 646/646 [==============================] - 51s 77ms/step - loss: 4.4282 - val_recall: 0.3685
# Epoch 9/100
# 646/646 [==============================] - 47s 70ms/step - loss: 4.0402 - val_recall: 0.3650
# Epoch 10/100
# 646/646 [==============================] - 49s 74ms/step - loss: 3.6998 - val_recall: 0.3652
# Epoch 11/100
# 646/646 [==============================] - 48s 72ms/step - loss: 3.4054 - val_recall: 0.3607
# Epoch 11: early stopping
# -----Starting trial25
# {'embed_dim': 200, 'hidden_dim': 200, 'threshold': 0.1}
# Epoch 1/100
# 646/646 [==============================] - 65s 86ms/step - loss: 10.0101 - val_recall: 0.0232
# Epoch 2/100
# 646/646 [==============================] - 53s 80ms/step - loss: 9.0052 - val_recall: 0.1178
# Epoch 3/100
# 646/646 [==============================] - 52s 79ms/step - loss: 7.6761 - val_recall: 0.2553
# Epoch 4/100
# 646/646 [==============================] - 54s 82ms/step - loss: 6.4788 - val_recall: 0.3328
# Epoch 5/100
# 646/646 [==============================] - 54s 83ms/step - loss: 5.5886 - val_recall: 0.3620
# Epoch 6/100
# 646/646 [==============================] - 50s 75ms/step - loss: 4.9019 - val_recall: 0.3718
# Epoch 7/100
# 646/646 [==============================] - 42s 63ms/step - loss: 4.3371 - val_recall: 0.3707
# Epoch 8/100
# 646/646 [==============================] - 42s 63ms/step - loss: 3.8611 - val_recall: 0.3673
# Epoch 9/100
# 646/646 [==============================] - 42s 63ms/step - loss: 3.4657 - val_recall: 0.3617
# Epoch 9: early stopping
# -----Starting trial26
# {'embed_dim': 200, 'hidden_dim': 200, 'threshold': 0.3}
# Epoch 1/100
# 646/646 [==============================] - 58s 74ms/step - loss: 10.0083 - val_recall: 0.0245
# Epoch 2/100
# 646/646 [==============================] - 47s 71ms/step - loss: 8.9543 - val_recall: 0.1180
# Epoch 3/100
# 646/646 [==============================] - 46s 70ms/step - loss: 7.6612 - val_recall: 0.2530
# Epoch 4/100
# 646/646 [==============================] - 46s 70ms/step - loss: 6.5059 - val_recall: 0.3256
# Epoch 5/100
# 646/646 [==============================] - 53s 80ms/step - loss: 5.6255 - val_recall: 0.3609
# Epoch 6/100
# 646/646 [==============================] - 55s 83ms/step - loss: 4.9352 - val_recall: 0.3697
# Epoch 7/100
# 646/646 [==============================] - 55s 84ms/step - loss: 4.3631 - val_recall: 0.3720
# Epoch 8/100
# 646/646 [==============================] - 45s 69ms/step - loss: 3.8796 - val_recall: 0.3652
# Epoch 9/100
# 646/646 [==============================] - 45s 67ms/step - loss: 3.4771 - val_recall: 0.3633
# Epoch 10/100
# 646/646 [==============================] - 45s 68ms/step - loss: 3.1470 - val_recall: 0.3591
# Epoch 10: early stopping
# -----Starting trial27
# {'embed_dim': 200, 'hidden_dim': 200, 'threshold': 0.5}
# Epoch 1/100
# 646/646 [==============================] - 60s 78ms/step - loss: 10.0043 - val_recall: 0.0244
# Epoch 2/100
# 646/646 [==============================] - 50s 75ms/step - loss: 8.9972 - val_recall: 0.1167
# Epoch 3/100
# 646/646 [==============================] - 49s 74ms/step - loss: 7.6672 - val_recall: 0.2558
# Epoch 4/100
# 646/646 [==============================] - 49s 75ms/step - loss: 6.4775 - val_recall: 0.3289
# Epoch 5/100
# 646/646 [==============================] - 52s 79ms/step - loss: 5.5952 - val_recall: 0.3615
# Epoch 6/100
# 646/646 [==============================] - 55s 84ms/step - loss: 4.9108 - val_recall: 0.3718
# Epoch 7/100
# 646/646 [==============================] - 51s 78ms/step - loss: 4.3473 - val_recall: 0.3688
# Epoch 8/100
# 646/646 [==============================] - 47s 71ms/step - loss: 3.8694 - val_recall: 0.3702
# Epoch 9/100
# 646/646 [==============================] - 44s 66ms/step - loss: 3.4699 - val_recall: 0.3647
# Epoch 9: early stopping

# %% [markdown]
# # ベストスコアの時のテスト評価を行う
# hidden_dim=150, embed_dim=200, threshold=0.3の時に最も良いスコアを出す

# %%
hidden_dim = 150
embed_dim = 200
threshold=0.3
update_count=200
learning_rate = 0.01

model = BCQRec(num_items, seq_len, hidden_dim, embed_dim, update_count=update_count)
model.compile(optimizer=tfk.optimizers.Adam(learning_rate=learning_rate))
model.build(input_shape=(1,seq_len))

hist = model.fit(
                train_data, 
                epochs=100, 
                validation_data=valid_data,
                validation_freq=1,
                callbacks=[
                    tfk.callbacks.TensorBoard(log_dir=log_dir), 
                    tfk.callbacks.ModelCheckpoint(
                        filepath=os.path.join(default_logdir, "params/BCQRec/checkpoint_%d_%d_%f"%(embed_dim, hidden_dim, threshold)),
                        save_weights_only=True,
                        monitor="val_recall",
                        mode="max",
                        save_best_only=True
                    ),
                    tfk.callbacks.EarlyStopping(
                        monitor="val_recall",
                        min_delta=1e-4,
                        patience=3,
                        mode="max",
                        verbose=1)])
# Out:
# Epoch 1/100
# 646/646 [==============================] - 127s 180ms/step - loss: 9.0323 - val_recall: 0.2790
# Epoch 2/100
# 646/646 [==============================] - 51s 77ms/step - loss: 6.9035 - val_recall: 0.3500
# Epoch 3/100
# 646/646 [==============================] - 120s 184ms/step - loss: 5.8244 - val_recall: 0.3644
# Epoch 4/100
# 646/646 [==============================] - 55s 83ms/step - loss: 4.9955 - val_recall: 0.3621
# Epoch 5/100
# 646/646 [==============================] - 120s 184ms/step - loss: 4.4873 - val_recall: 0.3525
# Epoch 6/100
# 646/646 [==============================] - 68s 104ms/step - loss: 4.0690 - val_recall: 0.3459
# Epoch 6: early stopping

# %%
test = pickle.load(open(
    "/home/inoue/work/dataset/%s/derived/mdp_test.df"%dataname, "rb"))

test_data = tf.data.Dataset.from_tensor_slices(
    (test[0],test[1],test[2])).shuffle(len(test[0])).batch(batch_size)

# %%
k =20
df = pd.DataFrame(columns=["sessionId", "recIds", "choiceId"])
for batch in tqdm(test_data):
    sess, state, target = batch
    q = model(state)
    
    topkitem = tf.math.top_k(q, k=k)[1].numpy() + 1
    tmp = pd.DataFrame(
        [sess.numpy(), topkitem, target.numpy()]).T
    tmp.columns = ["sessionId", "recIds", "choiceId"]
    df = pd.concat([df, tmp], axis=0)
# Out:
#   0%|          | 0/251 [00:00<?, ?it/s]

# %%
for k_ in [5, 10, 15, 20]:
    df["NDCG@%d"%k_] = df[["recIds", "choiceId"]].apply(lambda x: metrics.ndcg_at_k(x[1], x[0], k=k_), axis=1)
    df["Hit@%d"%k_] = df[["recIds", "choiceId"]].apply(lambda x: metrics.hit_at_k(x[1], x[0], k=k_), axis=1)

# %%
df.groupby("sessionId").mean().mean()
# Out:
# NDCG@5     0.087843
# Hit@5      0.094787
# NDCG@10    0.113483
# Hit@10     0.150045
# NDCG@15    0.128672
# Hit@15     0.189883
# NDCG@20    0.139226
# Hit@20     0.220834
# dtype: float64

# %%
df.to_csv("~/work/recs/results/bcq_test_result.csv")
